# %%
import pandas as pd
df=pd.read_csv("/content/tested .csv")

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))

sns.countplot(data=df, x="Pclass")

plt.title("Placement Count by Pclass")
plt.xlabel("Pclass")
plt.ylabel("Count")

plt.show()
