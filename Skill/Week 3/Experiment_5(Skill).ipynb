# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab/placement_dataset.csv')

# %%
import os
os.listdir('/content/drive/MyDrive/Colab')
# Out:
# ['placement_dataset.csv', 'placement_predict_50k Dataset (1).csv']

# %%
['placement_dataset.csv', 'placement_predict_50k Dataset (1).csv']
# Out:
# ['placement_dataset.csv', 'placement_predict_50k Dataset (1).csv']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

sns.set_style("whitegrid")

# %%
df = pd.read_csv("tested.csv")

# %%
num_cols = ['CGPA','IQ', 'Aptitude_Score', 'Communication_Skill']

# %%
fig1 = plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="Purples", yticklabels=False)
plt.title("Missingness Heatmap = Placement Prediction Dataset")
plt.xlabel("Columns")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab/placement_dataset.csv')
fig2, axes = plt.subplots(2, 3, figsize=(15,8))

for i, col in enumerate(num_cols):
  row,colpos = divmod(i,3)
  sns.histplot(df[col].dropna(), bins=30,kde=True,
               ax = axes[row,colpos],color='steelblue')
  axes[row,colpos].set_title(f'Distribution of {col}')
plt.tight_layout()
plt.show()
